# %%
import pandas as pd

# %% [markdown]
# Total number of files in the dataset

# %%
# !ls --almost-all -o ../data | wc -l
# Out:
# 3362

# %%
df = pd.read_csv('../data/-0.0332440668675476_-75.45230903823258.csv', delimiter=';')
df.head()
# Out:
#   lang                   id                created_at  \
# 0   es  1432423525642551297  2021-08-30T19:22:36.000Z
# 1   es  1431420873018380293  2021-08-28T00:58:25.000Z
# 2   es  1431309098021269517  2021-08-27T17:34:16.000Z
# 3   es  1430947724824825857  2021-08-26T17:38:17.000Z
# 4   es  1430332319513026561  2021-08-25T00:52:53.000Z
#
#                                                 text      conversation_id  \
# 0  @Mafercoronelq Ese mal hay en todo el país, sa...  1432422579873239045
# 1  En ceremonia realizada bajo todos los protocol...  1431420873018380293
# 2  Con una ceremonia, eucaristía y recorrido por ...  1431309098021269517
# 3  En el muelle principal de la #FlotillaFluvialD...  1430947724824825857
# 4  Qué hijueputa falta me hace visitar una librería.  1430332319513026561
#
#    in_reply_to_user_id reply_settings               source  \
# 0         1.593809e+09       everyone  Twitter for Android
# 1                  NaN       everyone   Twitter for iPhone
# ...
